# %% [markdown]
# # 🧪 LAB 2 — Segment Anything (SAM)
#
# ## Objective
# Apply modern segmentation using SAM.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install torch torchvision opencv-python matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load Image

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('bus.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(809.5), np.float64(1079.5), np.float64(-0.5))

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Out:
# --2026-03-30 14:56:23--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Resolviendo dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 54.230.144.2, 54.230.144.104, 54.230.144.28, ...
# Conectando con dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)[54.230.144.2]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 375042383 (358M) [binary/octet-stream]
# Guardando como: ‘sam_vit_b_01ec64.pth’
#
# sam_vit_b_01ec64.pt 100%[===================>] 357,67M  23,1MB/s    en 18s
#
# 2026-03-30 14:56:41 (20,2 MB/s) - ‘sam_vit_b_01ec64.pth’ guardado [375042383/375042383]

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Cargar imagen
img = cv2.imread('bus.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Cargar modelo SAM
sam = sam_model_registry["vit_b"](checkpoint="sam_vit_b_01ec64.pth")

mask_generator = SamAutomaticMaskGenerator(sam)

# Generar máscaras
masks = mask_generator.generate(img)

print(f"Se generaron {len(masks)} máscaras")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 16
#      13 mask_generator = SamAutomaticMaskGenerator(sam)
#      15 # Generar máscaras
# ---> 16 masks = mask_generator.generate(img)
#      18 print(f"Se generaron {len(masks)} máscaras")
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/segment_anything/automatic_mask_generator.py:163, in SamAutomaticMaskGenerator.generate(self, image)
#     138 """
# ...

# %% [markdown]
# ## Task
# - Use ChatGPT to integrate SAM
# - Generate segmentation masks

# %% [markdown]
# ## Modification
# - Select a point
# - Segment only that object

# %% [markdown]
# ## Questions
# 1. Difference: bounding box vs mask
# 2. Why SAM is zero-shot?
# 3. When use Detectron2?
