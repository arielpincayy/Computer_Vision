# %% [markdown]
# # **Lecture:** Instance Segmentation with YOLO

# %% [markdown]
# ![instance_segmentation](instance-segmentation.png)

# %% [markdown]
# This lab will guide you step-by-step through using YOLO for image segmentation (instance segmentation).
#
# You will learn:
#
# What image segmentation is and how it differs from other computer vision tasks
# How YOLO performs instance segmentation
# How to run inference on images and videos
# How to interpret and visualize segmentation masks

# %% [markdown]
# ### **Introduction:** YOLO Segmentation
#
# YOLO Segmentation extends traditional object detection by not only identifying objects in an image but also generating pixel-level masks that outline the exact shape of each detected object. Instead of predicting only bounding boxes, the model outputs a precise segmentation mask for each detected instance.
#
# ### **How It Works**
#
# YOLO segmentation models follow a single-stage pipeline:
#
# 1. The image is processed by a convolutional neural network.
# 2. The model detects objects (bounding boxes + class labels).
# 3. For each detected object, it predicts a **segmentation mask** - a binary matrix indicating which pixels belong to the object.
# 4. Each mask includes:
#     - **Pixel coordinates** defining the object boundary
#     - **Confidence score** for the detection
#     - This allows real-time performance, making it suitable for applications such as autonomous driving, medical imaging, and video editing.
#
# ### **Training Dataset**
#
# Most YOLO segmentation models are trained on the **COCO dataset** (Common Objects in Context), which includes:
#
# - Over 200,000 labeled images
# - 80 object categories
# - Instance segmentation masks for each object
# - Diverse real-world scenarios
# - YOLO Segmentation vs YOLO Object Detection vs YOLO Pose Estimation
#
# | Feature | YOLO Object Detection | YOLO Pose Estimation | YOLO Segmentation |
# |---------|----------------------|---------------------|-------------------|
# | Output | Bounding boxes + class labels | Bounding boxes + keypoints | Bounding boxes + class labels + masks |
# | Goal | Detect objects | Understand human body structure | Outline exact object boundaries |
# | Detail level | Object-level | Joint-level | Pixel-level |
# | Use cases | Counting, tracking | Activity recognition, gesture analysis | Medical imaging, background removal, autonomous driving |
#
# ### **Why Segmentation Matters**
#
# Unlike standard object detection or pose estimation, segmentation provides **pixel-level precision**, enabling higher-level tasks such as:
#
# - **Background removal & replacement**
#     - *Example:* Removing or blurring backgrounds in video calls, replacing backgrounds in photos.
# - **Medical image analysis**
#     - *Example:* Segmenting tumors, organs, or cells in medical scans for diagnosis.
# - **Autonomous driving**
#     - *Example:* Identifying road boundaries, pedestrians, vehicles, and obstacles with pixel accuracy.
# - **Robotics**
#     - *Example:* Precise object grasping and manipulation based on object shape.
# - **Image editing**
#     - *Example:* Changing colors of specific objects, adding effects to segmented regions.
#
# ---

# %% [markdown]
# ### **Step 1:** Install Dependencies
# Install the Ultralytics library, which provides YOLO.

# %%
# %pip install --upgrade pip setuptools wheel
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install matplotlib
# Out:
# Requirement already satisfied: pip in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (26.0.1)
# Requirement already satisfied: setuptools in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (82.0.1)
# Requirement already satisfied: wheel in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (0.46.3)
# Requirement already satisfied: packaging>=24.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from wheel) (26.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ultralytics in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (8.4.32)
# Requirement already satisfied: numpy>=1.23.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (1.39.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from polars>=0.20.0->ultralytics) (1.39.0)
# Requirement already satisfied: six>=1.5 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from opencv-python) (2.4.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **Step 2:** Import Libraries
# Load the necessary Python libraries.

# %%
# Import YOLO from Ultralytics
from ultralytics import YOLO  # Main class to load and run the model

# Import OpenCV for image visualization
import cv2  # Used to read and display images

# Import matplotlib for plotting
import matplotlib.pyplot as plt  # Used to display images in notebooks

# Import numpy for array operations
import numpy as np

# %% [markdown]
# ### **Step 3:** Load a Pretrained Segmentation Model
# YOLO provides pretrained segmentation models. We will use `yolo26n-seg.pt` (nano version: fast and lightweight).

# %%
# Load the pretrained YOLO segmentation model
model = YOLO('yolo26n-seg.pt')  # Loads a lightweight segmentation model

# %% [markdown]
# ### **Step 4:** Run Segmentation on an Image
# 1. Load an image
# 2. Run inference
# 3. Visualize segmentation masks

# %%
# Load an image
image = cv2.imread('dashcam.png')  # Replace with your image path

# Run inference
results = model(image)  # Model processes the image and predicts masks

# Extract first result
result = results[0]

# Plot results (bounding boxes + masks)
annotated_image = result.plot()  # Draws masks and bounding boxes on the image

# Convert BGR (OpenCV) to RGB for display
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Show image
plt.figure(figsize=(12, 8))
plt.imshow(annotated_image)
#plt.axis('off')
plt.show()
# Out:
# 0: 384x640 1 person, 8 cars, 72.1ms
# Speed: 2.4ms preprocess, 72.1ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### **Step 5:** Understanding the Output
#
# The model can detect 80 different object classes including:
#
# 0: person
# 1: bicycle
# 2: car
# 3: motorcycle
# 4: airplane
# 5: bus
# 6: train
# 7: truck
# 8: boat
# ... and many more (traffic lights, fire hydrant, stop sign, etc.)
#
# Each detected object has:
#
# - Bounding box (x1, y1, x2, y2)
# - Class label and confidence
# - Segmentation mask (polygon or binary mask)
#
# You can access raw segmentation data like this:

# %%
# Access segmentation data
masks = result.masks  # Contains mask information

if masks is not None:
    # Print mask shapes
    print(f"Number of masks: {len(masks)}")
    print(f"Mask data shape: {masks.data.shape}")  # (num_objects, height, width)
    
    # Access boxes and classes
    boxes = result.boxes
    print(f"Boxes: {boxes.xyxy}")  # Bounding box coordinates
    print(f"Classes: {boxes.cls}")  # Class IDs
    print(f"Confidences: {boxes.conf}")  # Confidence scores
    
    # Access mask polygons (for visualization)
    if hasattr(masks, 'xy'): # Check if polygon data is available
        print(f"Mask polygons: {masks.xy}")  # List of polygon points for each mask
# Out:
# Number of masks: 9
# Mask data shape: torch.Size([9, 384, 640])
# Boxes: tensor([[9.9290e-01, 2.7794e+02, 2.8724e+02, 6.9242e+02],
#         [5.4131e+02, 2.1682e+02, 6.3703e+02, 4.9134e+02],
#         [7.2709e+02, 2.8382e+02, 7.6036e+02, 3.1043e+02],
#         [8.1618e+02, 2.8254e+02, 8.5426e+02, 3.0801e+02],
#         [8.6571e+02, 2.8637e+02, 9.2261e+02, 3.2212e+02],
#         [1.0160e+03, 2.8013e+02, 1.1526e+03, 3.5969e+02],
#         [1.5541e+02, 6.0968e+02, 1.2470e+03, 6.9385e+02],
#         [7.9424e+02, 2.8325e+02, 8.1640e+02, 3.0402e+02],
#         [8.6644e+02, 2.8698e+02, 9.2131e+02, 3.2174e+02]], device='cuda:0')
# Classes: tensor([2., 0., 2., 2., 2., 2., 2., 2., 2.], device='cuda:0')
#        [     900.18,       317.6],
#        [     902.13,      319.54],
#        [     906.02,      319.54],
#        [     907.97,      321.49],
#        [     909.92,      319.54],
#        [     913.82,      319.54],
#        [     915.77,       317.6],
#        [     919.66,       317.6],
#        [     921.61,      319.54],
#        [      929.4,      319.54],
#        [      929.4,      296.16],
#        [     921.61,      296.16],
#        [     919.66,      294.21],
#        [     919.66,      284.47]], dtype=float32)]

# %% [markdown]
# ### **Step 6:** Visualizing Individual Masks
# You can extract and visualize individual segmentation masks:

# %%
# Step 1: Load image
image_path = 'dashcam.png'  # Path to your image
image = cv2.imread(image_path)  # Read image using OpenCV (BGR format)

# Get original image size (height, width)
h, w = image.shape[:2]

# Step 2: Run YOLO segmentation
result = model(image)[0]  # Run inference and take first result

# Step 3: Show global result (no boxes, no labels, no masks drawn)
img_plot = result.plot(boxes=False, labels=False, masks=False)  # Render clean image
img_plot = cv2.cvtColor(img_plot, cv2.COLOR_BGR2RGB)  # Convert BGR → RGB for matplotlib

# Display image
plt.imshow(img_plot)
plt.axis('off')
plt.title("Original Image (No Overlays)")
plt.show()

# Step 4: Process masks (if any detected)
if result.masks is not None:

    # Extract raw mask data (N, H, W). N = number of detected objects, H and W are YOLO input dimensions (e.g., 640x640).
    masks = result.masks.data.cpu().numpy() # Convert to NumPy array for processing.

    # Extract bounding boxes and class info
    boxes = result.boxes.xyxy.cpu().numpy() # Bounding box coordinates (x1, y1, x2, y2) scaled to YOLO input size 
    classes = result.boxes.cls.cpu().numpy() # Class IDs for each detected object
    confs = result.boxes.conf.cpu().numpy() # Confidence scores for each detected object

    # Get YOLO internal resolution
    mh, mw = masks.shape[1:] # Height and width of YOLO input (e.g., 640x640)

    # Convert original image to RGB once
    img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Convert original image to RGB for consistent plotting

    print(f"Detected objects: {len(masks)}") # Print number of detected objects

    # Step 5: Loop over each detected object
    for i, mask in enumerate(masks):

        plt.figure(figsize=(8, 6))  # Create new figure

        # Resize mask to original image size
        mask = cv2.resize(mask, (w, h))  # Match original resolution

        # Binarize mask (clean threshold)
        mask = (mask > 0.5).astype(float) # Convert to binary mask (0 or 1) for better visualization

        # Show original image
        plt.imshow(img_rgb) # Display original image as background

        # Overlay mask with transparency
        plt.imshow(mask, alpha=0.5) # Show mask with 50% transparency

        # Get class name
        label = model.names[int(classes[i])] # Get class name from model's class list using class ID

        # Title with class and confidence
        plt.title(f"{label} ({confs[i]:.2f})")
        plt.axis('off')
        plt.show()

        # Print mask area (number of pixels)
        print(f"{label}: {mask.sum():.0f} pixels")
# Out:
# 0: 384x640 1 person, 8 cars, 8.4ms
# Speed: 1.3ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected objects: 9
# car: 77372 pixels
# person: 11608 pixels
# car: 1048 pixels
# car: 1047 pixels
# car: 1989 pixels
# car: 6926 pixels
# car: 71055 pixels
# car: 598 pixels
# car: 1947 pixels

# %% [markdown]
# ### **Step 7:** Run Segmentation on Video
# We can also process video streams frame-by-frame.

# %%
# Run inference on a video file and save results
video_path = 'india_highway.mp4'  # Path to input video
output_path = 'annotated_video.mp4'  # Path to save annotated video

model(
    source=video_path,
    save=True,
    project='',
    name='india_highway_annotated'
    ,stream=True
)  # Runs inference on video and saves annotated output
# Out:
# <generator object BasePredictor.stream_inference at 0x73686fb7dfc0>

# %% [markdown]
# ### **Step 8:** Real-time Webcam Segmentation

# %%
# Run real-time segmentation on webcam
# Press 'q' to quit
model.predict(
    source=0,  # 0 for webcam
    show=True,  # Display the output
    save=False,
    conf=0.5  # Confidence threshold
)
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 2 persons, 1 chair, 638.5ms
# 0: 480x640 2 persons, 8.0ms
# 0: 480x640 2 persons, 9.4ms
# 0: 480x640 2 persons, 9.2ms
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/plugins"
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# 0: 480x640 2 persons, 1 chair, 10.1ms
# 0: 480x640 2 persons, 9.3ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 9.2ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 9.2ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 9.0ms
# 0: 480x640 2 persons, 1 chair, 8.3ms
# 0: 480x640 1 person, 8.5ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 3 persons, 1 chair, 8.2ms
# 0: 480x640 2 persons, 1 chair, 8.6ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 9.7ms
# 0: 480x640 2 persons, 9.5ms
# 0: 480x640 2 persons, 10.5ms
# 0: 480x640 2 persons, 9.5ms
# 0: 480x640 2 persons, 8.0ms
# 0: 480x640 3 persons, 8.2ms
# 0: 480x640 2 persons, 1 chair, 8.2ms
# 0: 480x640 3 persons, 8.1ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 1 chair, 8.0ms
# 0: 480x640 2 persons, 9.4ms
# 0: 480x640 2 persons, 1 chair, 9.3ms
# 0: 480x640 2 persons, 1 chair, 8.2ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 3 persons, 8.4ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 1 chair, 9.2ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 1 chair, 8.0ms
# 0: 480x640 2 persons, 7.9ms
# 0: 480x640 2 persons, 8.9ms
# 0: 480x640 3 persons, 1 chair, 8.0ms
# 0: 480x640 2 persons, 1 chair, 9.8ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 1 chair, 8.4ms
# 0: 480x640 2 persons, 1 chair, 8.4ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 3 persons, 8.2ms
# 0: 480x640 2 persons, 8.8ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 1 chair, 9.0ms
# 0: 480x640 2 persons, 9.6ms
# 0: 480x640 2 persons, 1 chair, 8.6ms
# 0: 480x640 2 persons, 1 chair, 8.4ms
# 0: 480x640 2 persons, 8.8ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 10.0ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 8.8ms
# 0: 480x640 2 persons, 8.9ms
# 0: 480x640 3 persons, 1 chair, 8.8ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 9.0ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 3 persons, 8.3ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 9.1ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 3 persons, 8.9ms
# 0: 480x640 2 persons, 9.7ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 1 chair, 1 laptop, 8.6ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.7ms
# 0: 480x640 2 persons, 9.0ms
# 0: 480x640 2 persons, 8.7ms
# 0: 480x640 3 persons, 1 chair, 8.4ms
# 0: 480x640 3 persons, 8.4ms
# 0: 480x640 2 persons, 9.1ms
# 0: 480x640 2 persons, 1 laptop, 8.0ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 1 chair, 8.2ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 9.2ms
# 0: 480x640 2 persons, 8.8ms
# 0: 480x640 1 person, 9.2ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 8.7ms
# 0: 480x640 1 person, 8.5ms
# 0: 480x640 2 persons, 1 chair, 9.2ms
# 0: 480x640 2 persons, 1 chair, 8.1ms
# 0: 480x640 2 persons, 1 chair, 8.3ms
# 0: 480x640 2 persons, 1 chair, 8.5ms
# 0: 480x640 3 persons, 8.4ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 7.9ms
# 0: 480x640 2 persons, 8.9ms
# 0: 480x640 2 persons, 1 chair, 8.4ms
# 0: 480x640 2 persons, 1 chair, 9.2ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 8.8ms
# 0: 480x640 2 persons, 1 chair, 1 laptop, 8.2ms
# 0: 480x640 2 persons, 1 chair, 8.5ms
# 0: 480x640 2 persons, 8.9ms
# 0: 480x640 2 persons, 9.2ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 3 persons, 8.6ms
# 0: 480x640 2 persons, 1 laptop, 8.4ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 1 laptop, 8.5ms
# 0: 480x640 2 persons, 1 chair, 1 laptop, 9.6ms
# 0: 480x640 2 persons, 1 laptop, 8.8ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 1 chair, 10.6ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 3 persons, 1 chair, 8.3ms
# 0: 480x640 2 persons, 1 chair, 8.4ms
# 0: 480x640 2 persons, 1 chair, 1 laptop, 8.7ms
# 0: 480x640 2 persons, 1 chair, 8.2ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 1 chair, 8.9ms
# 0: 480x640 2 persons, 1 chair, 8.7ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 1 chair, 8.2ms
# 0: 480x640 2 persons, 1 chair, 8.4ms
# 0: 480x640 2 persons, 1 chair, 8.5ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 3 persons, 8.0ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 1 laptop, 8.1ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 1 laptop, 8.4ms
# 0: 480x640 2 persons, 1 laptop, 8.2ms
# 0: 480x640 2 persons, 1 laptop, 8.2ms
# 0: 480x640 2 persons, 1 laptop, 8.4ms
# 0: 480x640 2 persons, 8.0ms
# 0: 480x640 2 persons, 1 laptop, 8.4ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 8.7ms
# 0: 480x640 3 persons, 1 chair, 8.1ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 1 laptop, 8.0ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 9.6ms
# 0: 480x640 2 persons, 1 chair, 8.7ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 1 laptop, 9.2ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 9.0ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.6ms
# 0: 480x640 2 persons, 1 laptop, 8.6ms
# 0: 480x640 2 persons, 1 laptop, 8.3ms
# 0: 480x640 2 persons, 1 laptop, 8.6ms
# 0: 480x640 2 persons, 1 chair, 1 laptop, 8.3ms
# 0: 480x640 2 persons, 1 laptop, 8.8ms
# 0: 480x640 2 persons, 1 laptop, 8.5ms
# 0: 480x640 2 persons, 1 laptop, 8.4ms
# 0: 480x640 2 persons, 1 chair, 1 laptop, 8.3ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 9.0ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 8.2ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 8.4ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.9ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 9.3ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 7.9ms
# 0: 480x640 1 person, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 1 person, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.7ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.8ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.7ms
# 0: 480x640 2 persons, 1 bottle, 7.9ms
# 0: 480x640 2 persons, 1 bottle, 8.7ms
# 0: 480x640 3 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 7.9ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 3 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 2 bottles, 10.6ms
# 0: 480x640 2 persons, 2 bottles, 8.0ms
# 0: 480x640 3 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 1 chair, 8.8ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 10.3ms
# 0: 480x640 1 person, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 1 chair, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 9.0ms
# 0: 480x640 2 persons, 1 bottle, 9.0ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 9.0ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.5ms
# 0: 480x640 3 persons, 1 bottle, 8.7ms
# 0: 480x640 3 persons, 1 bottle, 8.5ms
# 0: 480x640 3 persons, 1 bottle, 8.5ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 3 persons, 1 bottle, 9.0ms
# 0: 480x640 3 persons, 1 bottle, 8.6ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 3 persons, 1 bottle, 8.6ms
# 0: 480x640 3 persons, 1 bottle, 8.2ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.2ms
# 0: 480x640 3 persons, 1 bottle, 9.1ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.6ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.6ms
# 0: 480x640 3 persons, 1 bottle, 8.5ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.1ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.6ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.8ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.6ms
# 0: 480x640 3 persons, 1 bottle, 8.2ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.3ms
# 0: 480x640 3 persons, 1 bottle, 8.5ms
# 0: 480x640 3 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.8ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.7ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 2 bottles, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.7ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.6ms
# 0: 480x640 2 persons, 1 bottle, 8.7ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 1 person, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 2 bottles, 8.4ms
# 0: 480x640 1 person, 2 bottles, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 1 bottle, 8.3ms
# 0: 480x640 2 persons, 1 bottle, 8.2ms
# 0: 480x640 2 persons, 1 bottle, 8.4ms
# 0: 480x640 2 persons, 2 bottles, 9.0ms
# 0: 480x640 2 persons, 3 bottles, 8.3ms
# 0: 480x640 1 person, 1 bottle, 8.1ms
# 0: 480x640 2 persons, 1 bottle, 8.5ms
# 0: 480x640 2 persons, 1 bottle, 8.0ms
# 0: 480x640 2 persons, 1 bottle, 8.9ms
# 0: 480x640 2 persons, 1 bottle, 8.1ms
# 0: 480x640 1 person, 1 bottle, 8.5ms
# 0: 480x640 4 persons, 1 bottle, 8.1ms
# 0: 480x640 3 persons, 1 bottle, 8.2ms
# 0: 480x640 4 persons, 1 bottle, 8.4ms
# 0: 480x640 3 persons, 1 bottle, 8.5ms
# 0: 480x640 4 persons, 8.6ms
# 0: 480x640 3 persons, 8.5ms
# 0: 480x640 4 persons, 8.5ms
# 0: 480x640 4 persons, 8.2ms
# 0: 480x640 3 persons, 8.1ms
# 0: 480x640 3 persons, 1 laptop, 8.7ms
# 0: 480x640 3 persons, 10.4ms
# 0: 480x640 4 persons, 8.5ms
# 0: 480x640 3 persons, 8.3ms
# 0: 480x640 4 persons, 1 chair, 8.5ms
# 0: 480x640 3 persons, 8.3ms
# 0: 480x640 3 persons, 8.4ms
# 0: 480x640 4 persons, 8.2ms
# 0: 480x640 3 persons, 8.7ms
# 0: 480x640 3 persons, 1 chair, 8.3ms
# 0: 480x640 4 persons, 8.5ms
# 0: 480x640 3 persons, 8.4ms
# 0: 480x640 3 persons, 8.7ms
# 0: 480x640
ms
# 0: 480x640 1 person, 8.7ms
# 0: 480x640 1 person, 8.7ms
# 0: 480x640 1 person, 8.5ms
# 0: 480x640 1 person, 8.2ms
# 0: 480x640 1 person, 8.4ms
# 0: 480x640 2 persons, 8.1ms
# ...
#  obb: None
#  orig_img: array([[[110,  88,  73],
#          [109,  87,  72],
#          [110,  88,  73],
#          ...,
#          [135, 143, 159],
#          [133, 143, 159],
#          [133, 143, 159]],
#
#         [[112,  89,  75],
#          [112,  89,  75],
#          [109,  90,  75],
#          ...,
#          [139, 143, 158],
#          [137, 143, 158],
#          [137, 143, 158]],
#
#         [[111,  91,  76],
#          [111,  91,  76],
#          [111,  91,  74],
#          ...,
#          [141, 143, 156],
#          [142, 144, 157],
#          [141, 143, 156]],
#
#         ...,
#
#         [[ 10,  22,  20],
#          [ 12,  24,  22],
#          [ 14,  28,  21],
#          ...,
#          [112, 162, 197],
#          [112, 162, 195],
#          [113, 164, 196]],
#
#         [[  8,  28,  24],
#          [ 12,  31,  28],
#          [ 15,  33,  28],
#          ...,
#          [110, 161, 198],
#          [110, 162, 197],
#          [110, 162, 197]],
#
#         [[  9,  33,  29],
#          [ 11,  35,  31],
#          [ 14,  37,  31],
#          ...,
#          [109, 160, 197],
#          [109, 160, 197],
#          [110, 161, 198]]], shape=(480, 640, 3), dtype=uint8)
#  orig_shape: (480, 640)
#  path: '0'
#  probs: None
#  save_dir: '/home/ariel/Escritorio/proyectos/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/runs/segment/india_highway_annotated2'
#  speed: {'preprocess': 0.8853539999336135, 'inference': 8.236174000103347, 'postprocess': 0.5711839999094082},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[112,  92,  70],
#          [112,  92,  70],
#          [109,  88,  71],
#          ...,
#          [140, 140, 147],
#          [141, 138, 146],
#          [143, 141, 148]],
#
#         [[109,  92,  70],
#          [108,  91,  69],
#          [109,  90,  73],
#          ...,
#          [141, 141, 148],
#          [141, 141, 148],
#          [141, 141, 148]],
#
#         [[110,  89,  72],
#          [110,  89,  72],
#          [110,  89,  72],
#          ...,
#          [143, 143, 152],
#          [142, 142, 149],
#          [145, 145, 151]],
#
#         ...,
#
#         [[  3,  24,  23],
#          [  9,  29,  28],
#          [  9,  32,  31],
#          ...,
#          [126, 138, 163],
#          [126, 142, 164],
#          [128, 143, 165]],
#
#         [[  6,  27,  26],
#          [ 11,  32,  31],
#          [ 12,  37,  33],
#          ...,
#          [126, 138, 163],
#          [126, 141, 166],
#          [128, 142, 167]],
#
#         [[  9,  28,  32],
#          [ 12,  31,  35],
#          [ 12,  37,  33],
#          ...,
#          [127, 138, 166],
#          [126, 141, 166],
#          [126, 141, 166]]], shape=(480, 640, 3), dtype=uint8)
#  orig_shape: (480, 640)
#  path: '0'
#  probs: None
#  save_dir: '/home/ariel/Escritorio/proyectos/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/runs/segment/india_highway_annotated2'
#  speed: {'preprocess': 1.5483710000125939, 'inference': 9.620036000001164, 'postprocess': 1.010790000009365},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[110, 104,  69],
#          [109, 103,  68],
#          [107, 103,  69],
#          ...,
#          [144, 138, 148],
#          [144, 138, 150],
#          [146, 140, 152]],
#
#         [[109, 101,  72],
#          [109, 101,  72],
#          [108, 102,  74],
#          ...,
#          [144, 141, 151],
#          [143, 140, 150],
#          [144, 141, 151]],
#
#         [[108,  99,  73],
#          [109, 100,  74],
#          [109, 100,  74],
#          ...,
#          [147, 144, 151],
#          [144, 142, 149],
#          [144, 142, 149]],
#
#         ...,
#
#         [[  9,  22,  15],
#          [ 11,  25,  18],
#          [ 12,  28,  21],
#          ...,
#          [110, 122, 154],
#          [111, 124, 154],
#          [110, 123, 153]],
#
#         [[ 11,  26,  22],
#          [ 15,  30,  25],
#          [ 17,  33,  26],
#          ...,
#          [111, 123, 155],
#          [111, 123, 155],
#          [111, 123, 155]],
#
#         [[ 16,  28,  24],
#          [ 18,  31,  26],
#          [ 19,  35,  28],
#          ...,
#          [109, 124, 155],
#          [109, 124, 155],
#          [108, 122, 154]]], shape=(480, 640, 3), dtype=uint8)
#  orig_shape: (480, 640)
#  path: '0'
#  probs: None
#  save_dir: '/home/ariel/Escritorio/proyectos/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/runs/segment/india_highway_annotated2'
#  speed: {'preprocess': 0.9528209999416504, 'inference': 9.1301239999666, 'postprocess': 0.5900789999486733},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[115,  94,  75],
#          [116,  95,  76],
#          [105, 101,  65],
#          ...,
#          [150, 143, 157],
#          [155, 144, 157],
#          [156, 145, 158]],
#
#         [[113,  97,  77],
#          [113,  97,  77],
#          [107, 100,  74],
#          ...,
#          [152, 146, 158],
#          [151, 145, 155],
#          [152, 147, 157]],
#
#         [[115, 101,  81],
#          [115, 101,  81],
#          [108, 101,  79],
#          ...,
#          [151, 149, 156],
#          [152, 147, 155],
#          [152, 147, 155]],
#
#         ...,
#
#         [[  7,  20,  20],
#          [ 12,  26,  26],
#          [ 11,  30,  27],
#          ...,
#          [107, 133, 165],
#          [106, 132, 164],
#          [105, 131, 163]],
#
#         [[ 13,  24,  25],
#          [ 18,  29,  30],
#          [ 14,  33,  32],
#          ...,
#          [107, 134, 164],
#          [105, 131, 161],
#          [105, 131, 161]],
#
#         [[ 17,  28,  28],
#          [ 21,  33,  33],
#          [ 18,  36,  35],
#          ...,
#          [108, 133, 161],
#          [107, 131, 161],
#          [106, 130, 160]]], shape=(480, 640, 3), dtype=uint8)
#  orig_shape: (480, 640)
#  path: '0'
#  probs: None
#  save_dir: '/home/ariel/Escritorio/proyectos/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/runs/segment/india_highway_annotated2'
#  speed: {'preprocess': 1.1715320000575957, 'inference': 8.360306999975364, 'postprocess': 0.5927639999754319},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[114,  82,  76],
#          [120,  88,  82],
#          [120,  97,  83],
#          ...,
#          [151, 143, 160],
#          [148, 144, 156],
#          [149, 145, 157]],
#
#         [[112,  87,  75],
#          [117,  91,  80],
#          [118,  96,  82],
#          ...,
#          [152, 144, 161],
#          [149, 145, 157],
#          [149, 145, 157]],
#
#         [[113,  91,  74],
#          [115,  93,  76],
#          [117,  95,  80],
#          ...,
#          [148, 146, 160],
#          [148, 146, 160],
#          [149, 147, 161]],
#
#         ...,
#
#         [[  5,  26,  18],
#          [ 12,  33,  25],
#          [ 14,  39,  31],
#          ...,
#          [117, 133, 162],
#          [113, 131, 160],
#          [113, 131, 160]],
#
#         [[  7,  31,  22],
#          [ 12,  35,  27],
#          [ 14,  39,  31],
#          ...,
#          [121, 134, 162],
#          [117, 133, 160],
#          [116, 132, 159]],
#
#         [[ 10,  36,  27],
#          [ 12,  38,  29],
#          [ 14,  38,  32],
#          ...,
#          [123, 134, 162],
#          [119, 133, 160],
#          [117, 131, 158]]], shape=(480, 640, 3), dtype=uint8)
#  orig_shape: (480, 640)
#  path: '0'
#  probs: None
#  save_dir: '/home/ariel/Escritorio/proyectos/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/runs/segment/india_highway_annotated2'
#  speed: {'preprocess': 0.8610989999624508, 'inference': 9.237467000048127, 'postprocess': 0.7399810000379148},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[111,  99,  76],
#          [110,  97,  74],
#          [112, 104,  69],
#          ...,
#          [142, 136, 153],
#          [143, 138, 153],
#          [147, 142, 156]],
#
#         [[111,  99,  76],
#          [111,  99,  76],
#          [111, 101,  71],
#          ...,
#          [144, 139, 154],
#          [142, 140, 154],
#          [146, 143, 157]],
#
#         [[114, 101,  78],
#          [112, 100,  77],
#          [112, 101,  75],
#          ...,
#          [145, 143, 155],
#          [145, 143, 155],
#          [147, 145, 157]],
#
#         ...,
#
#         [[ 23,  20,  14],
#          [ 24,  21,  15],
#          [ 27,  26,  17],
#          ...,
#          [119, 135, 162],
#          [120, 137, 161],
#          [119, 135, 160]],
#
#         [[ 25,  29,  24],
#          [ 26,  30,  25],
#          [ 27,  32,  24],
#          ...,
#          [119, 135, 162],
#          [120, 137, 161],
#          [120, 137, 161]],
#
#         [[ 24,  32,  29],
#          [ 27,  35,  31],
#          [ 29,  35,  29],
#          ...,
#          [119, 135, 162],
#          [119, 135, 160],
#          [117, 134, 159]]], shape=(480, 640, 3), dtype=uint8)
#  orig_shape: (480, 640)
#  path: '0'
#  probs: None
#  save_dir: '/home/ariel/Escritorio/proyectos/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/runs/segment/india_highway_annotated2'
#  speed: {'preprocess': 0.8293589999084361, 'inference': 8.326162999992448, 'postprocess': 0.6305959999508559},
#  ...]

# %% [markdown]
# ### **Individual Activity**

# %% [markdown]
# #### **Activity Recognition using Segmentation**
#
# **Task:** Propose and implement an activity recognition task based on segmentation masks. For example:
#
# - Object **counting** in a specific region: Count how many cars are in a parking lot or how many people are in a room.
# - Object **size estimation**: Determine if a detected object is "large" or "small" based on its mask area.
# - **Background replacement**: Replace the background of detected persons with a custom image.
#
# **Requirements (5 points total):**
#
# - Clearly explain the selected activity and why it is relevant or useful. Describe the real-world application (e.g., safety monitoring, retail analytics, autonomous systems). Explicitly, why object detection is insufficient. (2 points)
#
# - Identify and describe the specific code you implemented or modified - line by line. Explain how you use the segmentation masks to perform your activity recognition. (2 points)
#
# - Show your system working in real-time. Deliver a live webcam demonstration (pre-recorded videos will not be evaluated). (2 points)

# %% [markdown]
# Following you have an easy example for person detection with specific object interaction: Detect if a person is holding a cellphone, carrying a backpack, or wearing a hat. This kind of easy examples where you just compare detected classes will not be graded.

# %%
from ultralytics import YOLO
import cv2

def detect_person_with_cellphone():
    model = YOLO('yolo26n-seg.pt')
    cap = cv2.VideoCapture(0)
    
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("No se pudo leer la cámara")
                break
            
            results = model(frame, verbose=False)
            result = results[0]
            
            has_person = False
            has_cellphone = False
            
            if result.boxes is not None:
                classes = result.boxes.cls.cpu().numpy()
                for cls in classes:
                    label = model.names[int(cls)]
                    if label == 'person':
                        has_person = True
                    elif label == 'cell phone':
                        has_cellphone = True
            
            status = "Person with cellphone detected!" if (has_person and has_cellphone) else "No cellphone detected"
            
            annotated = result.plot()
            cv2.putText(annotated, status, (30, 40),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            
            cv2.imshow('Segmentation', annotated)
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    finally:
        # 🔥 ESTO GARANTIZA QUE SE LIBERE SIEMPRE
        cap.release()
        cv2.destroyAllWindows()
        print("Cámara liberada correctamente")

# Run
detect_person_with_cellphone()
# Out:
# Cámara liberada correctamente

# %% [markdown]
# ### **Summary:**
#
# You have learned:
#
# - How to use YOLO for instance segmentation
# - How to run inference on images and videos
# - How to visualize and interpret segmentation masks
# - How to access individual masks and bounding boxes
# - How to create custom activity recognition using segmentation

# %% [markdown]
# ---
#
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>

# %%
from ultralytics import YOLO
import cv2
import numpy as np

def monitoreo_examen_heatmap():
    model = YOLO('yolo11n-seg.pt') 
    cap = cv2.VideoCapture(0)
    
    # --- Configuración del Heatmap ---
    ret, frame_info = cap.read()
    if not ret: return
    h, w, _ = frame_info.shape
    # Creamos un lienzo en negro para acumular el movimiento (float para precisión)
    acumulador_heatmap = np.zeros((h, w), dtype=np.float32)
    
    UMBRAL_PROXIMIDAD = 0.3 
    
    try:
        while True:
            ret, frame = cap.read()
            if not ret: break
            
            results = model(frame, verbose=False, classes=[0])
            result = results[0]
            
            areas_pixeles = []
            
            if result.masks is not None:
                # 1. Obtener máscaras
                # Redimensionamos la máscara al tamaño del frame original
                mascaras = result.masks.data.cpu().numpy()
                
                for i in range(len(mascaras)):
                    # Redimensionar máscara de la red (ej. 160x160) al tamaño de la cámara
                    mask_resized = cv2.resize(mascaras[i], (w, h))
                    
                    # 2. Acumulación de densidad (Solo para la persona principal/estudiante)
                    # El índice 0 suele ser la persona más cercana/grande detectada
                    if i == 0:
                        acumulador_heatmap += mask_resized * 0.05 # Velocidad de "llenado"
                    
                    conteo_pixeles = np.sum(mascaras[i] > 0)
                    areas_pixeles.append(conteo_pixeles)
            
            # --- Lógica de Alerta ---
            areas_pixeles.sort(reverse=True)
            status = "Estado: SEGURO"
            color = (0, 255, 0)
            
            if len(areas_pixeles) > 1:
                if areas_pixeles[1] > (areas_pixeles[0] * UMBRAL_PROXIMIDAD):
                    status = "ALERTA: Segunda presencia"
                    color = (0, 0, 255)

            # --- Generación Visual del Heatmap ---
            # Normalizamos y aplicamos color (COLORMAP_JET va de azul a rojo)
            heatmap_norm = cv2.normalize(acumulador_heatmap, None, 0, 255, cv2.NORM_MINMAX)
            heatmap_color = cv2.applyColorMap(heatmap_norm.astype(np.uint8), cv2.COLORMAP_JET)
            
            # Combinamos el frame original con el heatmap (transparencia)
            annotated_frame = result.plot(boxes=False, labels=False)
            display_frame = cv2.addWeighted(annotated_frame, 0.7, heatmap_color, 0.3, 0)
            
            # Interfaz de usuario
            cv2.putText(display_frame, status, (20, 50), cv2.FONT_HERSHEY_DUPLEX, 0.8, color, 2)
            cv2.putText(display_frame, "Densidad de movimiento acumulada", (20, h - 20), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

            cv2.imshow('Analisis de Densidad por Segmentacion', display_frame)
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                # Al salir, guardamos el reporte final como imagen
                cv2.imwrite('reporte_densidad_examen.png', display_frame)
                np.save('heatmap.npy', acumulador_heatmap)
                break
                
    finally:
        cap.release()
        cv2.destroyAllWindows()
        print("Reporte guardado y sistema cerrado.")
        print("Datos numéricos guardados en 'matriz_densidad.npy'.")

if __name__ == "__main__":
    monitoreo_examen_heatmap()
# Out:
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# Reporte guardado y sistema cerrado.
# Datos numéricos guardados en 'matriz_densidad.npy'.
