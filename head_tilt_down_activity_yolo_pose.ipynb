# %% [markdown]
# # **Lecture:** Pose Estimation with YOLO

# %% [markdown]
# ![pose_estimation](pose-estimation.png)

# %% [markdown]
# This lab will guide you step-by-step through using YOLO for human pose estimation.
#
# You will learn:
# - What pose estimation is
# - How YOLO performs keypoint detection
# - How to run inference on images and videos
# - How to interpret results

# %% [markdown]
# ### **Introduction:** YOLO Pose Estimation
#
# **YOLO Pose Estimation** extends traditional object detection by not only identifying people in an image but also locating key body joints (keypoints) such as the head, shoulders, elbows, and knees. Instead of predicting only bounding boxes, the model outputs a structured representation of the human body as a skeleton.
#
# ### **How It Works**
#
# YOLO Pose models follow a single-stage pipeline:
# 1. The image is processed by a convolutional neural network.
# 2. The model detects people (bounding boxes).
# 3. For each detected person, it predicts a fixed set of keypoints (e.g., 17 joints).
# 4. Each keypoint includes:
#    - **(x, y)** pixel coordinates
#    - **confidence score**
#
# This allows real-time performance, making it suitable for applications such as human-computer interaction, sports analysis, and surveillance.
#
# ### **Training Dataset**
#
# Most YOLO Pose models are trained on the **COCO Keypoints dataset** (Common Objects in Context), which includes:
# - Over 200,000 labeled images
# - 17 human body keypoints per person
# - Diverse real-world scenarios (different poses, occlusions, lighting conditions)
#
# The dataset defines a standard skeleton structure used across many pose estimation models.
#
# ### **YOLO Pose vs YOLO Object Detection**
#
# | Feature | YOLO Object Detection | YOLO Pose Estimation |
# |--------|----------------------|---------------------|
# | Output | Bounding boxes + class labels | Bounding boxes + keypoints |
# | Goal | Detect objects (person, car, etc.) | Understand human body structure |
# | Detail level | Object-level | Fine-grained (joint-level) |
# | Use cases | Counting, tracking, detection | Activity recognition, gesture analysis |
#
# ### **Why Pose Estimation Matters**
#
# Unlike standard object detection, pose estimation provides semantic information about **how a person is moving or positioned**, enabling higher-level tasks such as:
#
# - **Activity recognition**
#   *Example:* Detecting if a person is *raising their hand*, *sitting*, *walking*, or *squatting* based on joint positions and angles.
#
# - **Gesture control**
#   *Example:* Using hand or arm movements to control a system, such as raising a hand to trigger an event or moving arms to interact with a game or presentation.
#
# - **Biomechanical analysis**
#   *Example:* Measuring joint angles during exercises (e.g., squat depth, elbow angle in a bicep curl) to evaluate posture and prevent injuries.
#
# - **Behavior understanding**
#   *Example:* Identifying patterns like *fall detection*, or *unusual movement* in surveillance scenarios.

# %% [markdown]
# ___

# %% [markdown]
# ### **Step 1:** Install Dependencies
#
# We install the Ultralytics library, which provides YOLO.

# %%
# %pip install --upgrade pip setuptools wheel
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install matplotlib
#%pip install numpy==1.26.4 --force-reinstall
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.12/site-packages (26.0.1)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (82.0.1)
# Requirement already satisfied: wheel in ./.venv/lib/python3.12/site-packages (0.46.3)
# Requirement already satisfied: packaging>=24.0 in ./.venv/lib/python3.12/site-packages (from wheel) (26.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ultralytics in ./.venv/lib/python3.12/site-packages (8.4.32)
# Requirement already satisfied: numpy>=1.23.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in ./.venv/lib/python3.12/site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in ./.venv/lib/python3.12/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in ./.venv/lib/python3.12/site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in ./.venv/lib/python3.12/site-packages (from ultralytics) (1.39.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in ./.venv/lib/python3.12/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.0 in ./.venv/lib/python3.12/site-packages (from polars>=0.20.0->ultralytics) (1.39.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in ./.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in ./.venv/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in ./.venv/lib/python3.12/site-packages (from opencv-python) (2.4.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **Step 2:** Import Libraries
#
# We load the necessary Python libraries.

# %%
# Import YOLO from Ultralytics
from ultralytics import YOLO  # Main class to load and run the model

# Import OpenCV for image visualization
import cv2  # Used to read and display images

# Import matplotlib for plotting
import matplotlib.pyplot as plt  # Used to display images in notebooks
import numpy as np  # Numerical operations
from collections import deque  # Temporal smoothing for webcam predictions

# %% [markdown]
# ### **Step 3:** Load a Pretrained Pose Model
#
# YOLOv8 provides pretrained pose estimation models.
# We will use `yolo26n-pose.pt` (nano version: fast and lightweight).

# %%
# Load the pretrained YOLO pose model
model = YOLO('yolo26n-pose.pt')  # Loads a lightweight pose estimation model

# %% [markdown]
# ## **Step 4:** Run Pose Estimation on an Image
#
# We will:
# 1. Load an image
# 2. Run inference
# 3. Visualize keypoints

# %%
# Define image URL
#image = 'https://ultralytics.com/images/bus.jpg'  # Example image
image = cv2.imread('/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/zuck_running.jpg')  # Read image using OpenCV

# Run inference
results = model(image)  # Model processes the image and predicts keypoints

# Extract first result
result = results[0]  # YOLO returns a list, we take the first item

# Plot results
annotated_image = result.plot()  # Draws keypoints and skeleton on the image

# Convert BGR (OpenCV) to RGB for display
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(annotated_image)  # Display image
#plt.axis('off')  # Hide axis
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/assets'.
# [ WARN:0@2.049] global loadsave.cpp:278 findDecoder imread_('/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/zuck_running.jpg'): can't open/read file: check file path/integrity
# image 1/2 /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 57.4ms
# image 2/2 /home/ariel/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 65.9ms
# Speed: 1.7ms preprocess, 61.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### **Step 5:** Understanding the Output
#
# Each detected person has:
# - Bounding box
# - Keypoints (joints like elbows, knees, etc.)
#
# You can access raw keypoints like this:
#
# 0  Nose
# 1  Left eye
# 2  Right eye
# 3  Left ear
# 4  Right ear
# 5  Left shoulder
# 6  Right shoulder
# 7  Left elbow
# 8  Right elbow
# 9  Left wrist
# 10 Right wrist
# 11 Left hip
# 12 Right hip
# 13 Left knee
# 14 Right knee
# 15 Left ankle
# 16 Right ankle

# %% [markdown]
# ![body_coco](body_coco.png)

# %%
# Access keypoints data
keypoints = result.keypoints  # Contains all detected keypoints

# Print keypoints shape
print(keypoints.xy.shape)  # Shows the shape of the keypoints array (num_people, num_keypoints (COCO format), 2 (each point has x and y))

# ---Print keypoints---
# conf: confidence values for each keypoint, one vector per person, 17 keypoints in COCO format
# data: raw coordinates and confidence values, one vector per person, 17 keypoints in COCO format, with x, y, and confidence for each keypoint
# xy: combined array of coordinates, one vector per person, 17 keypoints in COCO format
#          [9.2451e-01, 5.1437e-01],
#          [9.8235e-01, 5.9791e-01],
#          [9.8437e-01, 5.9402e-01],
#          [9.3943e-01, 6.8380e-01],
#          [9.4297e-01, 6.7693e-01],
#          [8.9265e-01, 7.8368e-01],
#          [8.9517e-01, 7.7767e-01]],
#
#         [[3.6407e-01, 4.1539e-01],
#          [3.7062e-01, 4.0778e-01],
#          [3.5091e-01, 4.0890e-01],
#          [3.7868e-01, 4.1215e-01],
#          [3.2735e-01, 4.1509e-01],
#          [3.9510e-01, 4.5695e-01],
#          [3.0664e-01, 4.6076e-01],
#          [4.0896e-01, 5.0862e-01],
#          [2.9769e-01, 5.2390e-01],
#          [3.5103e-01, 4.9565e-01],
#          [3.2188e-01, 5.5093e-01],
#          [3.8530e-01, 5.8158e-01],
#          [3.2531e-01, 5.8404e-01],
#          [3.8594e-01, 6.6749e-01],
#          [3.2531e-01, 6.7606e-01],
#          [3.2885e-01, 7.2036e-01],
#          [3.3879e-01, 7.6466e-01]],
#
#         [[9.4982e-03, 5.2707e-01],
#          [5.0301e-03, 5.1976e-01],
#          [9.2163e-03, 5.1842e-01],
#          [3.9688e-04, 5.1851e-01],
#          [6.3929e-03, 5.1686e-01],
#          [1.9594e-03, 5.5398e-01],
#          [7.0241e-03, 5.5263e-01],
#          [1.6070e-02, 6.1645e-01],
#          [2.7323e-02, 6.2142e-01],
#          [4.9947e-02, 6.6708e-01],
#          [6.7751e-02, 6.6774e-01],
#          [7.4018e-03, 6.5933e-01],
#          [9.6830e-03, 6.5903e-01],
#          [1.0420e-02, 7.1480e-01],
#          [7.7187e-03, 7.1631e-01],
#          [1.1750e-02, 7.8562e-01],
#          [1.1283e-02, 7.8654e-01]]], device='cuda:0')

# %%
# Example: Accessing specific keypoint coordinates
keypoints.xy[0][5]  # (x, y) coordinates of left shoulder, first person, 6th keypoint (index 5)
# Out:
# tensor([157.6156, 491.3336], device='cuda:0')

# %%
# Example: Accessing specific keypoint data
keypoints.conf[0][5]  # confidence of left shoulder, first person, 6th keypoint (index 5)
# Out:
# tensor(0.9905, device='cuda:0')

# %% [markdown]
# ### **Step 6:** Run Pose Estimation on Video
#
# We can also process video streams frame-by-frame.

# %%
# Run inference on a video file and save results
video_path = '/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/jesper.mp4'  # Path to input video
output_path = '/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/jesper_annotated.mp4'  # Path to save annotated video
model(
    source=video_path,
    save=True,
    project='/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation',
    name='jesper_annotated'
)  # Runs inference on video and saves annotated output
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 video_path = '/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/jesper.mp4'  # Path to input video
#       3 output_path = '/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/jesper_annotated.mp4'  # Path to save annotated video
# ----> 4 model(
#       5     source=video_path,
#       6     save=True,
#       7     project='/Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation',
#       8     name='jesper_annotated'
#       9 )  # Runs inference on video and saves annotated output
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
#     534 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535     self.predictor.set_prompts(prompts)
# --> 536 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:226, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     224     return self.stream_inference(source, model, *args, **kwargs)
#     225 else:
# --> 226     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:300, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     296     self.setup_model(model)
#     298 with self._lock:  # for thread-safe inference
#     299     # Setup source every time predict is called
# --> 300     self.setup_source(source if source is not None else self.args.source)
#     302     # Check if save_dir/ label file exists
#     303     if self.args.save or self.args.save_txt:
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:257, in BasePredictor.setup_source(self, source, stride)
#     249 """Set up source and inference mode.
#     250
#     251 Args:
#    (...)    254     stride (int, optional): Model stride for image size checking.
#     255 """
#     256 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 257 self.dataset = load_inference_source(
#     258     source=source,
#     259     batch=self.args.batch,
#     260     vid_stride=self.args.vid_stride,
#     261     buffer=self.args.stream_buffer,
#     262     channels=getattr(self.model, "channels", 3),
#     263 )
#     264 self.source_type = self.dataset.source_type
#     265 if (
#     266     self.source_type.stream
#     267     or self.source_type.screenshot
#     268     or len(self.dataset) > 1000  # many images
#     269     or any(getattr(self.dataset, "video_flag", [False]))
#     270 ):  # long sequence
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/data/build.py:433, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     431     dataset = LoadPilAndNumpy(source, channels=channels)
#     432 else:
# --> 433     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     435 # Attach source types to the dataset
#     436 setattr(dataset, "source_type", source_type)
#
# File ~/Escritorio/proyectos/Computer_Vision/.venv/lib/python3.12/site-packages/ultralytics/data/loaders.py:368, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     366         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     367     else:
# --> 368         raise FileNotFoundError(f"{p} does not exist")
#     370 # Define files as images or videos
#     371 images, videos = [], []
#
# FileNotFoundError: /Users/eugenio/Documents/Computer_Vision/UC.05 Image Segmentation & Pose Estimation/jesper.mp4 does not exist

# %% [markdown]
# You have learned:
# - How to use YOLO for pose estimation
# - How to run inference on images and videos
# - How to visualize and interpret keypoints

# %% [markdown]
# ### **Individual Activity:**
# - Propose an activity recognition task (e.g., wrist above head -> raising hand, knees bent -> sitting/squatting, etc.).
# - Test the activity recognition task with your webcam.
# - Present your work in class (5 pts.)
#     - Clearly explain the selected activity and why it is relevant or useful (1 pt)
#     - Identify and describe the specific code you implemented or modified -line by line- (2 pts)
#     - Deliver a live webcam demonstration (pre-recorded videos will not be evaluated) (2 pts)

# %% [markdown]
# ---
#
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>

# %% [markdown]
# ## **Activity Solution:** Head Tilt Down Detection
#
# ### **Selected task**
# Detect when the user's **head is tilted downward**.
#
# ### **Why this activity matters**
# This activity can be used for:
# - **fatigue awareness**
# - **poor posture monitoring**
# - **basic ergonomic feedback** during computer use
#
# ### **Keypoints used**
# We will use the COCO body keypoints predicted by YOLO Pose:
# - `0` → nose
# - `5` → left shoulder
# - `6` → right shoulder
#
# ### **Detection idea**
# 1. Compute the **midpoint between both shoulders**.
# 2. Measure the **vertical distance** from the nose to the shoulder line.
# 3. Normalize that distance by the **shoulder width**.
# 4. If the normalized distance becomes too small, the head is considered **tilted downward**.
#
# This is a rule-based activity recognition layer built **on top of the pose estimation model**.

# %% [markdown]
# ### **Code for the activity recognition rule**
# The next cell implements the rule for detecting head tilt down.

# %%
# -----------------------------
# Parameters
# -----------------------------
CONF_THR = 0.40
HEAD_DOWN_RATIO_THR = 0.58
FRAMES_REQUIRED = 8

history = deque(maxlen=FRAMES_REQUIRED)


def get_keypoint(person_keypoints, idx):
    x = float(person_keypoints[idx][0])
    y = float(person_keypoints[idx][1])
    c = float(person_keypoints[idx][2])
    return x, y, c


def detect_head_tilt_down(person_keypoints, conf_thr=CONF_THR, ratio_thr=HEAD_DOWN_RATIO_THR):
    NOSE = 0
    LEFT_SHOULDER = 5
    RIGHT_SHOULDER = 6

    nose_x, nose_y, nose_conf = get_keypoint(person_keypoints, NOSE)
    ls_x, ls_y, ls_conf = get_keypoint(person_keypoints, LEFT_SHOULDER)
    rs_x, rs_y, rs_conf = get_keypoint(person_keypoints, RIGHT_SHOULDER)

    # Validate confidence
    if nose_conf < conf_thr or ls_conf < conf_thr or rs_conf < conf_thr:
        return False, None, None, None

    # Midpoint of shoulders
    shoulder_mid_x = (ls_x + rs_x) / 2.0
    shoulder_mid_y = (ls_y + rs_y) / 2.0

    # Shoulder width used for normalization
    shoulder_width = abs(rs_x - ls_x)

    if shoulder_width < 20:
        return False, None, None, None

    # Normalized vertical distance from nose to shoulder line
    neck_ratio = (shoulder_mid_y - nose_y) / shoulder_width

    # Smaller ratio means the head is lower
    head_down = neck_ratio < ratio_thr

    return head_down, neck_ratio, (int(shoulder_mid_x), int(shoulder_mid_y)), (int(nose_x), int(nose_y))

# %%
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Webcam could not be opened.")
else:
    print("Press 'q' to quit the webcam demo.")

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Frame could not be read.")
            break

        result = model(frame, verbose=False)[0]
        annotated_frame = result.plot()

        status_text = "No person detected"
        ratio_text = ""

        if result.keypoints is not None and result.keypoints.data is not None:
            keypoint_data = result.keypoints.data.cpu().numpy()

            if len(keypoint_data) > 0:
                # Select the person with the highest average keypoint confidence
                best_person = max(keypoint_data, key=lambda p: np.mean(p[:, 2]))

                detected, neck_ratio, shoulder_mid, nose_point = detect_head_tilt_down(best_person)

                history.append(1 if detected else 0)
                stable_detected = sum(history) >= int(0.7 * FRAMES_REQUIRED)

                if stable_detected:
                    status_text = "HEAD DOWN DETECTED"
                else:
                    status_text = "HEAD UP / NEUTRAL"

                if neck_ratio is not None:
                    ratio_text = f"ratio: {neck_ratio:.2f}"

                if shoulder_mid is not None and nose_point is not None:
                    cv2.line(annotated_frame, nose_point, shoulder_mid, (255, 255, 0), 2)
                    cv2.circle(annotated_frame, nose_point, 5, (0, 255, 255), -1)
                    cv2.circle(annotated_frame, shoulder_mid, 5, (255, 0, 255), -1)
            else:
                history.clear()
        else:
            history.clear()

        cv2.putText(
            annotated_frame,
            status_text,
            (20, 40),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255) if "DOWN" in status_text else (0, 255, 0),
            2
        )

        if ratio_text:
            cv2.putText(
                annotated_frame,
                ratio_text,
                (20, 80),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.8,
                (255, 255, 0),
                2
            )

        cv2.imshow("Head Tilt Down Detection", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# Press 'q' to quit the webcam demo.
